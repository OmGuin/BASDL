# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
path = r"C:\Users\omgui\Desktop\BASUS\sim_data\TentSim_v1p9p3_26Jun25-131718\Pre_v1p1_26Jun25-132620\Pre_v1p126Jun25-131718-preparams.par26Jun25-132620.npz"
data = np.load(path, allow_pickle=True)
amplitudes = data['handlesA'].item()['amplitude']
species = data['handlesA'].item()['species']

# %%
df = pd.DataFrame({
    'amplitudes':amplitudes,
    'species':species
})

# %%
print(f"min:{np.min(df['amplitudes'][df['species'] == 0])}")
print(f"mean:{np.mean(df['amplitudes'][df['species'] == 0])}")
print(f"max:{np.max(df['amplitudes'][df['species'] == 0])}")
amps = df['amplitudes'][df['species'] == 0]
bins = np.logspace(np.log10(min(amps)), np.log10(max(amps)), 20)
hist, bin_edges = np.histogram(amps, bins=bins)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

nonzero = hist > 0
x = bin_centers[nonzero]
y = hist[nonzero]

log_x = np.log10(x)
log_y = np.log10(y)
slope, intercept, r_value, p_value, std_err = linregress(log_x, log_y)
fit_y = 10**(slope * log_x + intercept)

plt.figure(figsize=(8, 6))
plt.loglog(x, y, '-ro', label='Amplitude')
plt.loglog(x, fit_y, '-bx', label=f'Power law: {slope:.2f}')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.title('Distribution of Burst Amplitudes')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.tight_layout()
plt.show()
# Out:
# min:41.2905703793883
# mean:274.80288709985706
# max:3436.3542018543944

# %%
print(f"min:{np.min(df['amplitudes'][df['species'] == 1])}")
print(f"mean:{np.mean(df['amplitudes'][df['species'] == 1])}")
print(f"max:{np.max(df['amplitudes'][df['species'] == 1])}")
amps = df['amplitudes'][df['species'] == 1]
bins = np.logspace(np.log10(min(amps)), np.log10(max(amps)), 20)
hist, bin_edges = np.histogram(amps, bins=bins)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

nonzero = hist > 0
x = bin_centers[nonzero]
y = hist[nonzero]

log_x = np.log10(x)
log_y = np.log10(y)
slope, intercept, r_value, p_value, std_err = linregress(log_x, log_y)
fit_y = 10**(slope * log_x + intercept)

plt.figure(figsize=(8, 6))
plt.loglog(x, y, '-ro', label='Amplitude')
plt.loglog(x, fit_y, '-bx', label=f'Power law: {slope:.2f}')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.title('Distribution of Burst Amplitudes')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.tight_layout()
plt.show()
# Out:
# min:41.32171800905687
# mean:380.97723791218976
# max:4619.261125591773

# %%
print(f"min:{np.min(df['amplitudes'][df['species'] == 2])}")
print(f"mean:{np.mean(df['amplitudes'][df['species'] == 2])}")
print(f"max:{np.max(df['amplitudes'][df['species'] == 2])}")
amps = df['amplitudes'][df['species'] == 2]
bins = np.logspace(np.log10(min(amps)), np.log10(max(amps)), 20)
hist, bin_edges = np.histogram(amps, bins=bins)
bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

nonzero = hist > 0
x = bin_centers[nonzero]
y = hist[nonzero]

log_x = np.log10(x)
log_y = np.log10(y)
slope, intercept, r_value, p_value, std_err = linregress(log_x, log_y)
fit_y = 10**(slope * log_x + intercept)

plt.figure(figsize=(8, 6))
plt.loglog(x, y, '-ro', label='Amplitude')
plt.loglog(x, fit_y, '-bx', label=f'Power law: {slope:.2f}')
plt.xlabel('Amplitude')
plt.ylabel('Frequency')
plt.title('Distribution of Burst Amplitudes')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.tight_layout()
plt.show()
# Out:
# min:41.29942687013055
# mean:483.54702415766525
# max:5294.438547920659

# %%
np.max(df['amplitudes'])
# Out:
# np.float64(5294.438547920659)

# %%
x = np.array([200, 190, 185, 186, 150, 140, 110, 130, 85, 80, 70, 60, 42, 40, 38, 27, 30, 17, 9, 3])

# %%
x.sum()
# Out:
# np.int64(1792)

# %%
def softmaxO(x):
    return np.array([np.exp(h)/(np.sum(np.exp(x))) for h in x])
def softmaxE(x):
    return np.array([h/np.sum(x) for h in x])

# %%
softmaxE(x)
# Out:
# array([0.11160714, 0.10602679, 0.10323661, 0.10379464, 0.08370536,
#        0.078125  , 0.06138393, 0.07254464, 0.04743304, 0.04464286,
#        0.0390625 , 0.03348214, 0.0234375 , 0.02232143, 0.02120536,
#        0.01506696, 0.01674107, 0.00948661, 0.00502232, 0.00167411])

# %%
import numpy as np
jawn = np.array([1,2,3,4])
np.savez_compressed("jawn.npz", shite = jawn)

# %%
ting = np.load("jawn.npz")
ting['shite']
# Out:
# array([1, 2, 3, 4])

# %%
print(f"{5:07}")
# Out:
# 0000005

# %%
import os
os.makedirs("dataset", exist_ok=True)

# %%
import numpy as np
odshf = np.array([2,3,4,1,2,2])
os.makedirs(os.path.join("dataset", "xyz"))
np.save(os.path.join(os.path.join("dataset", "xyz"), "fdoijf"), odshf)

# %%
import torch
x = torch.tensor([[1,2],[3,4],[5,6]])
x
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
x.unsqueeze(2)
# Out:
# tensor([[[1],
#          [2]],
#
#         [[3],
#          [4]],
#
#         [[5],
#          [6]]])
